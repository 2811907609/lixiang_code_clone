# %%
# ruff: noqa: E402

# %reload_ext autoreload
# %autoreload 2

import pandas as pd

from copilot_dashboard_analysis.ai_code_ratio import (
    AICodeRatioAnalysis,
    AICodeRatioData,
)
from copilot_dashboard_analysis.config import init_config_from_env

# Set pandas options to display all columns
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
pd.set_option('display.expand_frame_repr', False)

init_config_from_env('../.env')

# %%
start_date = '2025-01-01'

ai_code_data = AICodeRatioData(start_date=start_date)

ai_code_data.loaddata()

# %%
ana = AICodeRatioAnalysis(ai_code_data)
ai_gen_code = ana.calc_accepted_code()
user_added_code = ana.calc_user_commit_code()

# %%
ana.calc_stat(ai_gen_code, user_added_code)

# %%
# find very large commits

def find_large_commits(df):
    # find user with most added lines
    df.sort_values('user_added_lines', ascending=False).head(10)

    df1 = ana.combined_df

    df1 = df1[df1.author_email == 'huzijian1@lixiang.com']

    df1['insertions'] = pd.to_numeric(df1['insertions'], errors='coerce').astype('Int64')

    df1.sort_values('insertions', ascending=False).head(10)

# %%
start_date = '2025-01-01'

ai_code_data = AICodeRatioData(start_date=start_date)

ai_code_data.loaddata()
