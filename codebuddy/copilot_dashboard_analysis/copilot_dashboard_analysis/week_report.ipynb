# %%
# ruff: noqa: E402

# %reload_ext autoreload
# %autoreload 2

import pandas as pd
from IPython.display import display

from copilot_dashboard_analysis.config import init_config_from_env
from copilot_dashboard_analysis.week_report import WeekReport

# Set pandas options to display all columns
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
pd.set_option('display.expand_frame_repr', False)

init_config_from_env('../.env')

# %%
prev_dates = ('2024-12-25', '2025-01-01')
this_dates = ('2025-01-02', '2025-01-07')

report = WeekReport(
    prev_dates=prev_dates,
    this_dates=this_dates,
)

report.prepare()
report._this_filtered_df.head(2)

# %%
merged_df1 = report.analyze_recent_7d_by_user()
display(merged_df1.head())
merged_df1.to_csv('week_report_1.csv', index=False)

merged_df2 = report.analyze_recent_7d_by_l2department()
display(merged_df2.head())
merged_df2.to_csv('week_report_2.csv', index=False)

merged_df3 = report.analyze_recent_7d_by_lang()
display(merged_df3.head())
merged_df3.to_csv('week_report_3.csv', index=False)

merged_df4 = report.analyze_recent_7d_by_depart_lang()
display(merged_df4.head())
merged_df4.to_csv('week_report_4.csv', index=False)

merged_df5 = report.analyze_recent_7d_by_depart_lang_topk_users()
display(merged_df5.head())
merged_df5.to_csv('week_report_5.csv', index=False)

merged_df6 = report.analyze_recent_7d_by_model()
display(merged_df6.head())
merged_df6.to_csv('week_report_6.csv', index=False)

merged_df7 = report.analyze_7d_user_activity()
display(merged_df7.head())
merged_df7.to_csv('week_report_7.csv', index=False)
